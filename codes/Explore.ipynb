# %%
import sklearn
import pandas
import matplotlib.pyplot as plt
import graphlab as gl

# %%
bids = gl.SFrame.read_csv("../bids.csv")
train = gl.SFrame.read_csv("../train.csv")
# Out:
# PROGRESS: Finished parsing file /home/h6/Github/FB/bids.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 2.73152 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[int,str,str,str,str,int,str,str,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Read 438470 lines. Lines per second: 495900
# PROGRESS: Read 5205972 lines. Lines per second: 875203
# PROGRESS: Finished parsing file /home/h6/Github/FB/bids.csv
# PROGRESS: Parsing completed. Parsed 7656334 lines in 8.44048 secs.
# PROGRESS: Finished parsing file /home/h6/Github/FB/train.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.023437 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# ...

# %%
bids.head()
# Out:
# Columns:
# 	bid_id	int
# 	bidder_id	str
# 	auction	str
# 	merchandise	str
# 	device	str
# 	time	int
# 	country	str
# 	ip	str
# 	url	str
#
# Rows: 10
#
# Data:
# +--------+-------------------------------+---------+----------------+--------+
# | bid_id |           bidder_id           | auction |  merchandise   | device |
# +--------+-------------------------------+---------+----------------+--------+
# |   0    | 8dac2b259fd1c6d1120e519fb1... |  ewmzr  |    jewelry     | phone0 |
# |   1    | 668d393e858e8126275433046b... |  aeqok  |   furniture    | phone1 |
# |   2    | aa5f360084278b35d746fa6af3... |  wa00e  |   home goods   | phone2 |
# |   3    | 3939ac3ef7d472a59a9c5f893d... |  jefix  |    jewelry     | phone4 |
# |   4    | 8393c48eaf4b8fa96886edc7cf... |  jefix  |    jewelry     | phone5 |
# |   5    | e8291466de91b0eb4e1515143c... |  3vi4t  |     mobile     | phone7 |
# |   6    | eef4c687daf977f64fc1d08675... |  kjlzx  |     mobile     | phone2 |
# ...

# %%
bids[bids["bidder_id"]==train["bidder_id"][0]][:20]
# Out:
# Columns:
# 	bid_id	int
# 	bidder_id	str
# 	auction	str
# 	merchandise	str
# 	device	str
# 	time	int
# 	country	str
# 	ip	str
# 	url	str
#
# Rows: 20
#
# Data:
# +---------+-------------------------------+---------+-------------+-----------+
# |  bid_id |           bidder_id           | auction | merchandise |   device  |
# +---------+-------------------------------+---------+-------------+-----------+
# |  85371  | 91a3c57b13234af24875c56fb7... |  yitr4  |  home goods |  phone35  |
# |  274487 | 91a3c57b13234af24875c56fb7... |  btpyy  |  home goods | phone1004 |
# |  527436 | 91a3c57b13234af24875c56fb7... |  kj2ko  |  home goods |   phone4  |
# |  554135 | 91a3c57b13234af24875c56fb7... |  1m5t8  |  home goods |   phone4  |
# |  607628 | 91a3c57b13234af24875c56fb7... |  btpyy  |  home goods |   phone4  |
# |  666164 | 91a3c57b13234af24875c56fb7... |  1m5t8  |  home goods |  phone35  |
# |  700546 | 91a3c57b13234af24875c56fb7... |  0xo1d  |  home goods |   phone4  |
# ...

# %%
####### just use the number of each record.
###calculate auction
